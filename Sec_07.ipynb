# %%
import pandas as pd

#initialize data

data1 = {
    'Make':['atv/utv/snow'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'Component':['O-Ring'],
    
    
    'MPN':['BK-O-214'],
    
    'AD LIST ITEM NUMBER':['999905'],
    
    'Vendor Notes':['OEM# 293300086, 420230920, 420230923, 420650500; REF# 008-647; I.D: 60 X O.D: 65.15 X T: 2.65MM.']
}

#For this column = 'Model':['All Model']
#List All Models
list_models = [

'Expedition 600 TUV Yeti II',
'Expedition 600 TUV REV-XU',
'Expedition 600 SE',
'Expedition 600',
'Expedition 1200 SE',
'Expedition 1200',
'Expedition SE 4-TEC 1200',
'Expedition LE 4-TEC 1200',
'Expedition Sport 600 ACE',
'Expedition Sport ACE 900',
'Expedition SE ACE 900',
'Expedition LE ACE 900',
'Expedition SWT ACE 900',
'Expedition SE ACE 900 Turbo',
'Expedition LE ACE 900 Turbo',
'Expedition SWT ACE 900 Turbo',
'Expedition LE ACE 900 Turbo R',
'Expedition SE ACE 900 Turbo R',
'Expedition Xtreme ACE 900 Turbo R',
'Grand Touring Sport 600 ACE',
'Grand Touring LE ACE 900',
'Grand Touring SE ACE 900',
'Grand Touring Limited ACE 900',
'Grand Touring Limited ACE 900 Turbo',
'Grand Touring Sport ACE 900',
'Grand Touring Limited ACE 900 Turbo R',
'GSX 1200 Limited',
'GSX 1200 SE',
'GSX LE ACE 900',
'MX Z 600',
'MX Z 600RS',
'MX Z 600 Renegade X',
'MX Z 600 Blizzard',
'MX Z 600 Adrenaline',
'MX Z 600 Trail',
'MX Z 600 X',
'MX Z 600 Sport',
'MX Z 600 R Sport',
'MX Z 600 Renegade',
'MX Z 600 R X',
'MX Z 1200 X',
'MX Z 1200 Renegade X',
'MX Z 1200 TNT',
'MX Z 600 TNT',
'MX Z 1200 Renegade',
'MX Z 600 X-RS',
'MX Z 1200 Adrenaline',
'MX Z X-RS E-TEC 600 HO',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT 600 ACE',
'MX Z X-RS 600',
'MX Z TNT 4-TEC 1200',
'MX Z TNT 600 Carb',
'MX Z TNT ACE 900',
'MX Z 600 50th Anniversary',
'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z 600 TNT Early Edition',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'Renegade Adrenaline ACE 900',
'Skandic SWT ACE 900',
'Skandic WT ACE 900',
'Renegade Enduro ACE 900',
'Renegade Adrenaline ACE 900 Turbo',
'Renegade Enduro ACE 900 Turbo',
'Renegade X ACE 900 Turbo',
'Renegade X-RS ACE 900 Turbo',
'Renegade Adrenaline ACE 900 Turbo R',
'Renegade X-RS ACE 900 Turbo R',
'Renegade Enduro ACE 900 Turbo R',
'Renegade X ACE 900 Turbo R',
'Skandic 600 WT',
'Skandic 600 SUV',
'Renegade 600 Adrenaline',
'Renegade Backcountry X E-TEC 600 HO',
'Renegade X E-TEC 600 HO',
'Renegade Backcountry E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600 HO',
'Renegade Sport 600 ACE',
'Skandic WT E-TEC 600 HO',
'Skandic WT 600 ACE',
'Skandic WT 600',
'Skandic Tundra LT 600 ACE',
'Skandic SWT E-TEC 600 HO',
'Skandic SWT ACE 600',
'Renegade Sport 600 Carb',
'Renegade Enduro E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600R',
'Renegade Enduro E-TEC 600R',
'Renegade X E-TEC 600R',
'Renegade Sport 600 EFI',
'Skandic SWT E-TEC 600R',
'Skandic WT E-TEC 600R',
'Skandic WT 600 EFI',
'Skandic Sport 600 EFI',
'Renegade X-RS with Comp Package E-TEC 600R',
'Skandic LE 600 ACE',
'Skandic LE 600 EFI',
'Skandic LE E-TEC 600R',
'Skandic SE E-TEC 600R'

]

#Range of Years in Raw Data given

years = list(range(2011,2024))

#Functions/Syntax to Generate the Dataframe/ Tables

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames or Tables created
final_df = pd.concat(dfs, ignore_index = True)
                     
#Display or Print 
final_df
# Out:
#               Make                                       Model Vendor Code  \
# 0     atv/utv/snow                  Expedition 600 TUV Yeti II        NACH
# 1     atv/utv/snow                   Expedition 600 TUV REV-XU        NACH
# 2     atv/utv/snow                           Expedition 600 SE        NACH
# 3     atv/utv/snow                              Expedition 600        NACH
# 4     atv/utv/snow                          Expedition 1200 SE        NACH
# ...            ...                                         ...         ...
# 1386  atv/utv/snow  Renegade X-RS with Comp Package E-TEC 600R        NACH
# 1387  atv/utv/snow                          Skandic LE 600 ACE        NACH
# 1388  atv/utv/snow                          Skandic LE 600 EFI        NACH
# 1389  atv/utv/snow                       Skandic LE E-TEC 600R        NACH
# 1390  atv/utv/snow                       Skandic SE E-TEC 600R        NACH
#
#                         Vendor Name Component       MPN AD LIST ITEM NUMBER  \
# 0     NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 1     NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 2     NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 3     NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 4     NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# ...                             ...       ...       ...                 ...
# 1386  NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 1387  NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 1388  NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 1389  NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
# 1390  NACHMAN INTERNATIONAL CO. LTD    O-Ring  BK-O-214              999905
#
#                                            Vendor Notes  Year
# 0     OEM# 293300086, 420230920, 420230923, 42065050...  2011
# 1     OEM# 293300086, 420230920, 420230923, 42065050...  2011
# 2     OEM# 293300086, 420230920, 420230923, 42065050...  2011
# 3     OEM# 293300086, 420230920, 420230923, 42065050...  2011
# 4     OEM# 293300086, 420230920, 420230923, 42065050...  2011
# ...                                                 ...   ...
# 1386  OEM# 293300086, 420230920, 420230923, 42065050...  2023
# 1387  OEM# 293300086, 420230920, 420230923, 42065050...  2023
# 1388  OEM# 293300086, 420230920, 420230923, 42065050...  2023
# 1389  OEM# 293300086, 420230920, 420230923, 42065050...  2023
# 1390  OEM# 293300086, 420230920, 420230923, 42065050...  2023
#
# [1391 rows x 9 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\SECTION 7 TO 12\Sec_07 Merge\1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#initialize data

data1 = {
    'Make':['atv/utv/snow'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'Component':['Oil Filter'],
    
    
    'MPN':['SM-07163'],
    
    'AD LIST ITEM NUMBER':['120322'],
    
    'Vendor Notes':['(OLD ITEM) + O-RING 999905']
}

#For this column = 'Model':['All Model']
#List All Models
list_models = [

'Expedition 600 TUV Yeti II',
'Expedition 600 TUV REV-XU',
'Expedition 600 SE',
'Expedition 600',
'Expedition 1200 SE',
'Expedition 1200',
'Expedition SE 4-TEC 1200',
'Expedition LE 4-TEC 1200',
'Expedition Sport 600 ACE',
'Expedition Sport ACE 900',
'Expedition SE ACE 900',
'Expedition LE ACE 900',
'Expedition SWT ACE 900',
'Expedition SE ACE 900 Turbo',
'Expedition LE ACE 900 Turbo',
'Expedition SWT ACE 900 Turbo',
'Expedition LE ACE 900 Turbo R',
'Expedition SE ACE 900 Turbo R',
'Expedition Xtreme ACE 900 Turbo R',
'Grand Touring Sport 600 ACE',
'Grand Touring LE ACE 900',
'Grand Touring SE ACE 900',
'Grand Touring Limited ACE 900',
'Grand Touring Limited ACE 900 Turbo',
'Grand Touring Sport ACE 900',
'Grand Touring Limited ACE 900 Turbo R',
'GSX 1200 Limited',
'GSX 1200 SE',
'GSX LE ACE 900',
'MX Z 600',
'MX Z 600RS',
'MX Z 600 Renegade X',
'MX Z 600 Blizzard',
'MX Z 600 Adrenaline',
'MX Z 600 Trail',
'MX Z 600 X',
'MX Z 600 Sport',
'MX Z 600 R Sport',
'MX Z 600 Renegade',
'MX Z 600 R X',
'MX Z 1200 X',
'MX Z 1200 Renegade X',
'MX Z 1200 TNT',
'MX Z 600 TNT',
'MX Z 1200 Renegade',
'MX Z 600 X-RS',
'MX Z 1200 Adrenaline',
'MX Z X-RS E-TEC 600 HO',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT 600 ACE',
'MX Z X-RS 600',
'MX Z TNT 4-TEC 1200',
'MX Z TNT 600 Carb',
'MX Z TNT ACE 900',
'MX Z 600 50th Anniversary',
'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z 600 TNT Early Edition',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'Renegade Adrenaline ACE 900',
'Skandic SWT ACE 900',
'Skandic WT ACE 900',
'Renegade Enduro ACE 900',
'Renegade Adrenaline ACE 900 Turbo',
'Renegade Enduro ACE 900 Turbo',
'Renegade X ACE 900 Turbo',
'Renegade X-RS ACE 900 Turbo',
'Renegade Adrenaline ACE 900 Turbo R',
'Renegade X-RS ACE 900 Turbo R',
'Renegade Enduro ACE 900 Turbo R',
'Renegade X ACE 900 Turbo R',
'Skandic 600 WT',
'Skandic 600 SUV',
'Renegade 600 Adrenaline',
'Renegade Backcountry X E-TEC 600 HO',
'Renegade X E-TEC 600 HO',
'Renegade Backcountry E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600 HO',
'Renegade Sport 600 ACE',
'Skandic WT E-TEC 600 HO',
'Skandic WT 600 ACE',
'Skandic WT 600',
'Skandic Tundra LT 600 ACE',
'Skandic SWT E-TEC 600 HO',
'Skandic SWT ACE 600',
'Renegade Sport 600 Carb',
'Renegade Enduro E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600R',
'Renegade Enduro E-TEC 600R',
'Renegade X E-TEC 600R',
'Renegade Sport 600 EFI',
'Skandic SWT E-TEC 600R',
'Skandic WT E-TEC 600R',
'Skandic WT 600 EFI',
'Skandic Sport 600 EFI',
'Renegade X-RS with Comp Package E-TEC 600R',
'Skandic LE 600 ACE',
'Skandic LE 600 EFI',
'Skandic LE E-TEC 600R',
'Skandic SE E-TEC 600R'

]

#Range of Years in Raw Data given

years = list(range(2011,2024))

#Functions/Syntax to Generate the Dataframe/ Tables

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames or Tables created
final_df = pd.concat(dfs, ignore_index = True)
                     
#Display or Print 
final_df
# Out:
#               Make                                       Model Vendor Code  \
# 0     atv/utv/snow                  Expedition 600 TUV Yeti II        NACH
# 1     atv/utv/snow                   Expedition 600 TUV REV-XU        NACH
# 2     atv/utv/snow                           Expedition 600 SE        NACH
# 3     atv/utv/snow                              Expedition 600        NACH
# 4     atv/utv/snow                          Expedition 1200 SE        NACH
# ...            ...                                         ...         ...
# 1386  atv/utv/snow  Renegade X-RS with Comp Package E-TEC 600R        NACH
# 1387  atv/utv/snow                          Skandic LE 600 ACE        NACH
# 1388  atv/utv/snow                          Skandic LE 600 EFI        NACH
# 1389  atv/utv/snow                       Skandic LE E-TEC 600R        NACH
# 1390  atv/utv/snow                       Skandic SE E-TEC 600R        NACH
#
#                         Vendor Name   Component       MPN AD LIST ITEM NUMBER  \
# 0     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 1     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 2     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 3     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 4     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# ...                             ...         ...       ...                 ...
# 1386  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 1387  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 1388  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 1389  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
# 1390  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163              120322
#
#                     Vendor Notes  Year
# 0     (OLD ITEM) + O-RING 999905  2011
# 1     (OLD ITEM) + O-RING 999905  2011
# 2     (OLD ITEM) + O-RING 999905  2011
# 3     (OLD ITEM) + O-RING 999905  2011
# 4     (OLD ITEM) + O-RING 999905  2011
# ...                          ...   ...
# 1386  (OLD ITEM) + O-RING 999905  2023
# 1387  (OLD ITEM) + O-RING 999905  2023
# 1388  (OLD ITEM) + O-RING 999905  2023
# 1389  (OLD ITEM) + O-RING 999905  2023
# 1390  (OLD ITEM) + O-RING 999905  2023
#
# [1391 rows x 9 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\SECTION 7 TO 12\Sec_07 Merge\2.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#initialize data

data1 = {
    'Make':['atv/utv/snow'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'Component':['Oil Filter'],
    
    
    'MPN':['SM-07163-1'],
    
    'AD LIST ITEM NUMBER':['1101026'],
    
    'Vendor Notes':['OEM# 420230923, 420956123; REF# 006-559K, 008-647; H= 74MM, OD= 56.6 MM, TOP SEAL ID= 24.5MM W/ CHECK VALVE SPRING INSIDE. WITH O-RING I.D: 60 X O.D: 65.15 X T: 2.65MM.']
}

#For this column = 'Model':['All Model']
#List All Models
list_models = [

'Expedition 600 TUV Yeti II',
'Expedition 600 TUV REV-XU',
'Expedition 600 SE',
'Expedition 600',
'Expedition 1200 SE',
'Expedition 1200',
'Expedition SE 4-TEC 1200',
'Expedition LE 4-TEC 1200',
'Expedition Sport 600 ACE',
'Expedition Sport ACE 900',
'Expedition SE ACE 900',
'Expedition LE ACE 900',
'Expedition SWT ACE 900',
'Expedition SE ACE 900 Turbo',
'Expedition LE ACE 900 Turbo',
'Expedition SWT ACE 900 Turbo',
'Expedition LE ACE 900 Turbo R',
'Expedition SE ACE 900 Turbo R',
'Expedition Xtreme ACE 900 Turbo R',
'Grand Touring Sport 600 ACE',
'Grand Touring LE ACE 900',
'Grand Touring SE ACE 900',
'Grand Touring Limited ACE 900',
'Grand Touring Limited ACE 900 Turbo',
'Grand Touring Sport ACE 900',
'Grand Touring Limited ACE 900 Turbo R',
'GSX 1200 Limited',
'GSX 1200 SE',
'GSX LE ACE 900',
'MX Z 600',
'MX Z 600RS',
'MX Z 600 Renegade X',
'MX Z 600 Blizzard',
'MX Z 600 Adrenaline',
'MX Z 600 Trail',
'MX Z 600 X',
'MX Z 600 Sport',
'MX Z 600 R Sport',
'MX Z 600 Renegade',
'MX Z 600 R X',
'MX Z 1200 X',
'MX Z 1200 Renegade X',
'MX Z 1200 TNT',
'MX Z 600 TNT',
'MX Z 1200 Renegade',
'MX Z 600 X-RS',
'MX Z 1200 Adrenaline',
'MX Z X-RS E-TEC 600 HO',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT 600 ACE',
'MX Z X-RS 600',
'MX Z TNT 4-TEC 1200',
'MX Z TNT 600 Carb',
'MX Z TNT ACE 900',
'MX Z 600 50th Anniversary',
'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z 600 TNT Early Edition',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'Renegade Adrenaline ACE 900',
'Skandic SWT ACE 900',
'Skandic WT ACE 900',
'Renegade Enduro ACE 900',
'Renegade Adrenaline ACE 900 Turbo',
'Renegade Enduro ACE 900 Turbo',
'Renegade X ACE 900 Turbo',
'Renegade X-RS ACE 900 Turbo',
'Renegade Adrenaline ACE 900 Turbo R',
'Renegade X-RS ACE 900 Turbo R',
'Renegade Enduro ACE 900 Turbo R',
'Renegade X ACE 900 Turbo R',
'Skandic 600 WT',
'Skandic 600 SUV',
'Renegade 600 Adrenaline',
'Renegade Backcountry X E-TEC 600 HO',
'Renegade X E-TEC 600 HO',
'Renegade Backcountry E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600 HO',
'Renegade Sport 600 ACE',
'Skandic WT E-TEC 600 HO',
'Skandic WT 600 ACE',
'Skandic WT 600',
'Skandic Tundra LT 600 ACE',
'Skandic SWT E-TEC 600 HO',
'Skandic SWT ACE 600',
'Renegade Sport 600 Carb',
'Renegade Enduro E-TEC 600 HO',
'Renegade Adrenaline E-TEC 600R',
'Renegade Enduro E-TEC 600R',
'Renegade X E-TEC 600R',
'Renegade Sport 600 EFI',
'Skandic SWT E-TEC 600R',
'Skandic WT E-TEC 600R',
'Skandic WT 600 EFI',
'Skandic Sport 600 EFI',
'Renegade X-RS with Comp Package E-TEC 600R',
'Skandic LE 600 ACE',
'Skandic LE 600 EFI',
'Skandic LE E-TEC 600R',
'Skandic SE E-TEC 600R'

]

#Range of Years in Raw Data given

years = list(range(2010,2024))

#Functions/Syntax to Generate the Dataframe/ Tables

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames or Tables created
final_df = pd.concat(dfs, ignore_index = True)
                     
#Display or Print 
final_df
# Out:
#               Make                                       Model Vendor Code  \
# 0     atv/utv/snow                  Expedition 600 TUV Yeti II        NACH
# 1     atv/utv/snow                   Expedition 600 TUV REV-XU        NACH
# 2     atv/utv/snow                           Expedition 600 SE        NACH
# 3     atv/utv/snow                              Expedition 600        NACH
# 4     atv/utv/snow                          Expedition 1200 SE        NACH
# ...            ...                                         ...         ...
# 1493  atv/utv/snow  Renegade X-RS with Comp Package E-TEC 600R        NACH
# 1494  atv/utv/snow                          Skandic LE 600 ACE        NACH
# 1495  atv/utv/snow                          Skandic LE 600 EFI        NACH
# 1496  atv/utv/snow                       Skandic LE E-TEC 600R        NACH
# 1497  atv/utv/snow                       Skandic SE E-TEC 600R        NACH
#
#                         Vendor Name   Component         MPN  \
# 0     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 1     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 2     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 3     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 4     NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# ...                             ...         ...         ...
# 1493  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 1494  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 1495  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 1496  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
# 1497  NACHMAN INTERNATIONAL CO. LTD  Oil Filter  SM-07163-1
#
#      AD LIST ITEM NUMBER                                       Vendor Notes  \
# 0                1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 1                1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 2                1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 3                1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 4                1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# ...                  ...                                                ...
# 1493             1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 1494             1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 1495             1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 1496             1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
# 1497             1101026  OEM# 420230923, 420956123; REF# 006-559K, 008-...
#
#       Year
# 0     2010
# 1     2010
# 2     2010
# 3     2010
# 4     2010
# ...    ...
# 1493  2023
# 1494  2023
# 1495  2023
# 1496  2023
# 1497  2023
#
# [1498 rows x 9 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\SECTION 7 TO 12\Sec_07 Merge\3.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#initialize data

data1 = {
    'Make':['atv/utv/snow'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'Component':['Fuel Pump Seal'],
    
    
    'MPN':['SM-07263'],
    
    'AD LIST ITEM NUMBER':['1101027'],
    
    'Vendor Notes':['OEM# 513033862; OD:88MM (3.46"); ID:77.4MM (3.05"); T:5.3MM (0.21"); HARNDESS 70(+/-5); MATERIAL: VITON 70']
}

#For this column = 'Model':['All Model']
#List All Models
list_models = [

'Backcountry E-TEC 850',
'Backcountry E-TEC 600R',
'Backcountry Sport 600 EFI',
'Expedition 600 TUV Yeti II',
'Expedition 600 TUV REV-XU',
'Expedition 600 SE',
'Expedition 600',
'Expedition Sport ACE 900',
'Expedition SE ACE 900',
'Expedition LE ACE 900',
'Expedition SWT ACE 900',
'Expedition SE ACE 900 Turbo',
'Expedition LE ACE 900 Turbo',
'Expedition SWT ACE 900 Turbo',
'Expedition LE ACE 900 Turbo R',
'Expedition SE ACE 900 Turbo R',
'Expedition Xtreme ACE 900 Turbo R',
'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride S-38 E-TEC 850 154',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 165',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146'


]

#Range of Years in Raw Data given

years = list(range(2017,2024))

#Functions/Syntax to Generate the Dataframe/ Tables

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames or Tables created
final_df = pd.concat(dfs, ignore_index = True)
                     
#Display or Print 
final_df
